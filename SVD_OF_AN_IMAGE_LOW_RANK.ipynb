# %%
import numpy as np
import pandas as pd
import cv2 as cv
from skimage import io
from PIL import Image
import matplotlib.pylab as plt
import matplotlib.pyplot as p

# %%
url="https://th.bing.com/th/id/R.e9ea962e02082e7e2c7f3815a71a8364?rik=j34ZRvwSEhWP6A&riu=http%3a%2f%2fwww.pixelstalk.net%2fwp-content%2fuploads%2f2016%2f07%2fFree-4k-Backgrounds-Screen-Download.jpg&ehk=z%2f7Q4nlcVzNOT4%2f8vtJUjBFs3p%2fzurkacBEpNuTsIqM%3d&risl=&pid=ImgRaw&r=0"
image=io.imread(url)
grey_image=cv.cvtColor(image,cv.COLOR_BGR2GRAY)
print(image)
plt.imshow(image)
plt.imshow(grey_image)
# Out:
# [[[108  99  82]
#   [109 100  83]
#   [110 101  84]
#   ...
#   [188 144  73]
#   [191 147  76]
#   [192 148  77]]
#
#  [[107  98  81]
#   [108  99  82]
#   [109 100  83]
#   ...
#   [191 147  76]
#   [193 149  78]
#   [195 151  80]]
#
#  [[106  97  80]
#   [106  97  80]
#   [107  98  81]
#   ...
#   [193 149  78]
#   [195 151  80]
#   [196 152  81]]
#
#  ...
#
#  [[  4   0   0]
#   [  4   0   0]
#   [  4   0   0]
#   ...
#   [  9  11   8]
#   [  8  10   7]
#   [  0   2   0]]
#
#  [[ 10   6   5]
#   [  4   0   0]
#   [  3   0   0]
#   ...
#   [  2   4   1]
#   [  1   3   0]
#   [  0   1   0]]
#
#  [[ 42  38  37]
#   [ 34  30  29]
#   [ 29  25  22]
#   ...
#   [  4   6   3]
#   [  2   4   1]
#   [  8  10   7]]]
